# %% [markdown]
# # Part 2 · Meaning as geometry
#
# **Building Agentic AI — Day 1, 10:10–11:00**
#
# In Part 1 the model turned text into text. In this part we turn text into
# **numbers** — vectors — and discover that *similar meanings land close together*.
# This single idea powers semantic search, RAG, and your Day-3 agent's retrieval tool.
#
# Plan: a 10-minute `numpy` speedrun → dot products & cosine similarity by hand →
# real Gemini embeddings.

# %%
import os
import time

import numpy as np
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv("../.env", override=True)
client = genai.Client()

EMBED_MODEL = "gemini-embedding-001"

# %% [markdown]
# ## 1. numpy speedrun (only what we need)
#
# `numpy` arrays are the substrate of all machine learning: fixed-type grids of
# numbers with *fast* math.

# %%
v = np.array([1.0, 3.0, -2.0])

print("vector:", v)
print("shape:", v.shape, "· dtype:", v.dtype)
print("v * 2:", v * 2)          # elementwise — no loop needed
print("v + v:", v + v)
# Out:
# vector: [ 1.  3. -2.]
# shape: (3,) · dtype: float64
# v * 2: [ 2.  6. -4.]
# v + v: [ 2.  6. -4.]

# %% [markdown]
# The reason everyone uses numpy — vectorized math runs in optimized C, not in the
# Python interpreter:

# %%
big = np.random.default_rng(0).random(2_000_000)

t0 = time.perf_counter()
total_loop = sum(x * x for x in big)          # plain Python
t1 = time.perf_counter()
total_np = np.dot(big, big)                   # numpy
t2 = time.perf_counter()

print(f"python loop: {t1 - t0:.3f}s · numpy: {t2 - t1:.4f}s · same answer: {np.isclose(total_loop, total_np)}")
# Out:
# python loop: 0.246s · numpy: 0.0070s · same answer: True

# %% [markdown]
# One more tool we'll need this afternoon: **finding the best entries** in an array.

# %%
scores = np.array([0.12, 0.94, 0.51, 0.88, 0.07])

print("highest value:", scores.max())
print("index of highest:", scores.argmax())
print("indices, best→worst:", np.argsort(scores)[::-1])   # argsort is ascending, so we flip it
# Out:
# highest value: 0.94
# index of highest: 1
# indices, best→worst: [1 3 2 0 4]

# %% [markdown]
# `argsort` + slicing = "top-k results" — that *is* the heart of a search engine.
# Remember it for Part 3.

# %% [markdown]
# ## 2. Vectors as coordinates of meaning — a toy universe
#
# Forget AI for a second. Let's rate a few games *by hand* on just two axes:
# how **cozy** and how **action-packed** they are (0 to 1).

# %%
import matplotlib.pyplot as plt

toy = {
    "Dungeon Sprouts":   [0.95, 0.30],   # [coziness, action]
    "Rooftop Ramen":     [0.90, 0.35],
    "Neon Drift Racers": [0.15, 0.90],
    "Speedrun Sandwich": [0.40, 0.85],
    "Silent Depths":     [0.05, 0.60],
    "Bureau of Time":    [0.55, 0.25],
}

fig, ax = plt.subplots(figsize=(7, 5))
for name, (x, y) in toy.items():
    ax.scatter(x, y, s=80)
    ax.annotate(name, (x, y), xytext=(6, 4), textcoords="offset points")
ax.set_xlabel("coziness →")
ax.set_ylabel("action →")
ax.set_title("Six games in 'meaning space' (hand-made, 2 dimensions)")
plt.show()

# %% [markdown]
# Games with a similar *vibe* sit close together. That closeness is something we
# can **compute** — and that's the entire trick.
#
# Real embedding models do exactly this, except:
#
# - the axes are **learned from data**, not chosen by us,
# - there are **hundreds to thousands** of them, not 2,
# - and no single axis means anything readable — only *distances* matter.

# %% [markdown]
# ## 3. Dot product → cosine similarity, by hand
#
# The **dot product** multiplies vectors element-by-element and sums:
# $a \cdot b = \sum_i a_i b_i$. It's big when vectors point the same way.

# %%
a = np.array(toy["Dungeon Sprouts"])
b = np.array(toy["Rooftop Ramen"])
c = np.array(toy["Neon Drift Racers"])

manual = a[0] * b[0] + a[1] * b[1]
print("by hand:  ", manual)
print("np.dot:   ", np.dot(a, b))
print("vs racer: ", np.dot(a, c))
# Out:
# by hand:   0.96
# np.dot:    0.96
# vs racer:  0.4125

# %% [markdown]
# One flaw: the dot product also grows with vector *length*, so "loud" vectors win
# even when their direction is off. Fix: compare **directions only** — divide by both
# lengths. That's **cosine similarity**:
#
# $\text{cos}(a,b) = \dfrac{a \cdot b}{\lVert a\rVert \, \lVert b \rVert} \in [-1, 1]$
#
# `+1` same direction · `0` unrelated · `−1` opposite.

# %%
def cosine(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))


print("cozy vs cozy:     ", round(cosine(a, b), 3))
print("cozy vs racer:    ", round(cosine(a, c), 3))
print("v vs 100*v (same direction):", round(cosine(a, a * 100), 3))
# Out:
# cozy vs cozy:      0.998
# cozy vs racer:     0.454
# v vs 100*v (same direction): 1.0

# %% [markdown]
# You just wrote the function that ranks every search result, RAG lookup and
# recommendation this week. Four lines, no framework.

# %% [markdown]
# ## 4. Real embeddings from Gemini
#
# Now we let a trained model place **whole sentences** into a 768-dimensional
# meaning space.

# %%
sentences = [
    "The boss fight was brutally difficult but fair.",
    "I couldn't beat the final boss, way too hard.",
    "The soundtrack is absolutely gorgeous.",
    "Muzica din jocul ăsta e superbă.",
    "The game crashes every time I open the map.",
    "Constant freezes whenever I fast-travel.",
    "Best co-op experience I've had in years.",
    "My sourdough bread came out perfect today.",
]

result = client.models.embed_content(
    model=EMBED_MODEL,
    contents=sentences,
    config=types.EmbedContentConfig(
        task_type="SEMANTIC_SIMILARITY",
        output_dimensionality=768,
    ),
)

E = np.array([e.values for e in result.embeddings])
E = E / np.linalg.norm(E, axis=1, keepdims=True)   # normalize → cosine becomes a plain dot product
print("embeddings shape:", E.shape)
# Out:
# embeddings shape: (8, 768)

# %% [markdown]
# Each sentence is now a point in 768-dimensional space. Here's what "meaning"
# looks like as numbers (first 8 of 768 coordinates):

# %%
print(sentences[0])
print(np.round(E[0, :8], 3), "...")
# Out:
# The boss fight was brutally difficult but fair.
# [-0.011 -0.019  0.021 -0.121 -0.049  0.016  0.048 -0.001] ...

# %% [markdown]
# Since every row is normalized, `E @ E.T` computes the cosine similarity of
# **every pair at once** — your `cosine()` function, vectorized:

# %%
import pandas as pd

labels = ["boss-hard", "boss-cant", "soundtrack", "muzica-RO", "crash-map", "freeze-travel", "coop", "sourdough"]
sim = pd.DataFrame(E @ E.T, index=labels, columns=labels)
sim.style.background_gradient(cmap="RdYlGn", vmin=0, vmax=1).format("{:.2f}")
# Out:
# <style type="text/css">
# #T_2f405_row0_col0, #T_2f405_row1_col1, #T_2f405_row2_col2, #T_2f405_row3_col3, #T_2f405_row4_col4, #T_2f405_row5_col5, #T_2f405_row6_col6, #T_2f405_row7_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2f405_row0_col1, #T_2f405_row1_col0 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_2f405_row0_col2, #T_2f405_row2_col0, #T_2f405_row3_col4, #T_2f405_row4_col3 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_2f405_row0_col3, #T_2f405_row0_col6, #T_2f405_row3_col0, #T_2f405_row6_col0 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_2f405_row0_col4, #T_2f405_row4_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_2f405_row0_col5, #T_2f405_row5_col0 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_2f405_row0_col7, #T_2f405_row7_col0 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_2f405_row1_col2, #T_2f405_row2_col1, #T_2f405_row5_col7, #T_2f405_row7_col5 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_2f405_row1_col3, #T_2f405_row1_col6, #T_2f405_row3_col1, #T_2f405_row6_col1 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_2f405_row1_col4, #T_2f405_row4_col1 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_2f405_row1_col5, #T_2f405_row5_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_2f405_row1_col7, #T_2f405_row7_col1 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_2f405_row2_col3, #T_2f405_row3_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_2f405_row2_col4, #T_2f405_row4_col2 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_2f405_row2_col5, #T_2f405_row5_col2 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_2f405_row2_col6, #T_2f405_row6_col2 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_2f405_row2_col7, #T_2f405_row7_col2 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_2f405_row3_col5, #T_2f405_row5_col3 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_2f405_row3_col6, #T_2f405_row6_col3, #T_2f405_row6_col7, #T_2f405_row7_col6 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_2f405_row3_col7, #T_2f405_row7_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_2f405_row4_col5, #T_2f405_row5_col4 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_2f405_row4_col6, #T_2f405_row6_col4 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_2f405_row4_col7, #T_2f405_row7_col4 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_2f405_row5_col6, #T_2f405_row6_col5 {
#   background-color: #b3df72;
#   color: #000000;
# }
# </style>
# <table id="T_2f405">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f405_level0_col0" class="col_heading level0 col0" >boss-hard</th>
#       <th id="T_2f405_level0_col1" class="col_heading level0 col1" >boss-cant</th>
#       <th id="T_2f405_level0_col2" class="col_heading level0 col2" >soundtrack</th>
#       <th id="T_2f405_level0_col3" class="col_heading level0 col3" >muzica-RO</th>
#       <th id="T_2f405_level0_col4" class="col_heading level0 col4" >crash-map</th>
#       <th id="T_2f405_level0_col5" class="col_heading level0 col5" >freeze-travel</th>
#       <th id="T_2f405_level0_col6" class="col_heading level0 col6" >coop</th>
#       <th id="T_2f405_level0_col7" class="col_heading level0 col7" >sourdough</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f405_level0_row0" class="row_heading level0 row0" >boss-hard</th>
#       <td id="T_2f405_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_2f405_row0_col1" class="data row0 col1" >0.84</td>
#       <td id="T_2f405_row0_col2" class="data row0 col2" >0.69</td>
#       <td id="T_2f405_row0_col3" class="data row0 col3" >0.71</td>
#       <td id="T_2f405_row0_col4" class="data row0 col4" >0.70</td>
#       <td id="T_2f405_row0_col5" class="data row0 col5" >0.70</td>
#       <td id="T_2f405_row0_col6" class="data row0 col6" >0.71</td>
#       <td id="T_2f405_row0_col7" class="data row0 col7" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_2f405_level0_row1" class="row_heading level0 row1" >boss-cant</th>
#       <td id="T_2f405_row1_col0" class="data row1 col0" >0.84</td>
#       <td id="T_2f405_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_2f405_row1_col2" class="data row1 col2" >0.65</td>
#       <td id="T_2f405_row1_col3" class="data row1 col3" >0.68</td>
#       <td id="T_2f405_row1_col4" class="data row1 col4" >0.74</td>
#       <td id="T_2f405_row1_col5" class="data row1 col5" >0.72</td>
#       <td id="T_2f405_row1_col6" class="data row1 col6" >0.68</td>
#       <td id="T_2f405_row1_col7" class="data row1 col7" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_2f405_level0_row2" class="row_heading level0 row2" >soundtrack</th>
#       <td id="T_2f405_row2_col0" class="data row2 col0" >0.69</td>
#       <td id="T_2f405_row2_col1" class="data row2 col1" >0.65</td>
#       <td id="T_2f405_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_2f405_row2_col3" class="data row2 col3" >0.90</td>
#       <td id="T_2f405_row2_col4" class="data row2 col4" >0.65</td>
#       <td id="T_2f405_row2_col5" class="data row2 col5" >0.66</td>
#       <td id="T_2f405_row2_col6" class="data row2 col6" >0.78</td>
#       <td id="T_2f405_row2_col7" class="data row2 col7" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_2f405_level0_row3" class="row_heading level0 row3" >muzica-RO</th>
#       <td id="T_2f405_row3_col0" class="data row3 col0" >0.71</td>
#       <td id="T_2f405_row3_col1" class="data row3 col1" >0.68</td>
#       <td id="T_2f405_row3_col2" class="data row3 col2" >0.90</td>
#       <td id="T_2f405_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_2f405_row3_col4" class="data row3 col4" >0.69</td>
#       <td id="T_2f405_row3_col5" class="data row3 col5" >0.67</td>
#       <td id="T_2f405_row3_col6" class="data row3 col6" >0.79</td>
#       <td id="T_2f405_row3_col7" class="data row3 col7" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_2f405_level0_row4" class="row_heading level0 row4" >crash-map</th>
#       <td id="T_2f405_row4_col0" class="data row4 col0" >0.70</td>
#       <td id="T_2f405_row4_col1" class="data row4 col1" >0.74</td>
#       <td id="T_2f405_row4_col2" class="data row4 col2" >0.65</td>
#       <td id="T_2f405_row4_col3" class="data row4 col3" >0.69</td>
#       <td id="T_2f405_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_2f405_row4_col5" class="data row4 col5" >0.83</td>
#       <td id="T_2f405_row4_col6" class="data row4 col6" >0.64</td>
#       <td id="T_2f405_row4_col7" class="data row4 col7" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_2f405_level0_row5" class="row_heading level0 row5" >freeze-travel</th>
#       <td id="T_2f405_row5_col0" class="data row5 col0" >0.70</td>
#       <td id="T_2f405_row5_col1" class="data row5 col1" >0.72</td>
#       <td id="T_2f405_row5_col2" class="data row5 col2" >0.66</td>
#       <td id="T_2f405_row5_col3" class="data row5 col3" >0.67</td>
#       <td id="T_2f405_row5_col4" class="data row5 col4" >0.83</td>
#       <td id="T_2f405_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_2f405_row5_col6" class="data row5 col6" >0.67</td>
#       <td id="T_2f405_row5_col7" class="data row5 col7" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_2f405_level0_row6" class="row_heading level0 row6" >coop</th>
#       <td id="T_2f405_row6_col0" class="data row6 col0" >0.71</td>
#       <td id="T_2f405_row6_col1" class="data row6 col1" >0.68</td>
#       <td id="T_2f405_row6_col2" class="data row6 col2" >0.78</td>
#       <td id="T_2f405_row6_col3" class="data row6 col3" >0.79</td>
#       <td id="T_2f405_row6_col4" class="data row6 col4" >0.64</td>
#       <td id="T_2f405_row6_col5" class="data row6 col5" >0.67</td>
#       <td id="T_2f405_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_2f405_row6_col7" class="data row6 col7" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_2f405_level0_row7" class="row_heading level0 row7" >sourdough</th>
#       <td id="T_2f405_row7_col0" class="data row7 col0" >0.69</td>
#       <td id="T_2f405_row7_col1" class="data row7 col1" >0.67</td>
#       <td id="T_

# %% [markdown]
# Read the matrix — three things should jump out:
#
# 1. **Synonyms cluster**: *crash-map* ↔ *freeze-travel* score high with zero shared words.
# 2. **Languages don't matter**: *soundtrack* ↔ *muzica-RO* — the model maps Romanian
#    and English into the **same** meaning space.
# 3. **Sourdough is lonely**: lowest similarity against everything. As it should be.

# %% [markdown]
# And a preview of this afternoon — finding the closest sentence to a query is
# `argsort` on one matrix-vector product:

# %%
query = "the game keeps dying on startup"

q = np.array(
    client.models.embed_content(
        model=EMBED_MODEL,
        contents=query,
        config=types.EmbedContentConfig(task_type="SEMANTIC_SIMILARITY", output_dimensionality=768),
    ).embeddings[0].values
)
q = q / np.linalg.norm(q)

for i in np.argsort(E @ q)[::-1][:3]:
    print(f"{(E @ q)[i]:.3f}  {sentences[i]}")
# Out:
# 0.846  The game crashes every time I open the map.
# 0.795  Constant freezes whenever I fast-travel.
# 0.784  I couldn't beat the final boss, way too hard.

# %% [markdown]
# ## 5. Exercises
#
# **5.1 — Odd one out (⭐)** Write `odd_one_out(sentences)` that embeds a list and
# returns the sentence with the *lowest average similarity* to the others.
# Test it on `sentences` above (we all know who it is), then invent a sneakier list.
#
# **5.2 — Vectorized cosine matrix (⭐⭐)** Write `cosine_matrix(A)` that computes
# all-pairs cosine similarity for *any* (unnormalized) matrix `A`, without loops.
# Verify against nested `cosine()` calls using `np.allclose`.
#
# **5.3 — Your languages (⭐)** Write the same sentence in two languages you speak,
# plus one unrelated sentence. Check that meaning beats language.
#
# **5.4 — Shrinking dimensions (⭐⭐)** Re-embed `sentences` with
# `output_dimensionality=128`. Does the *ranking* of similarities change much?
# (Gemini embeddings are trained so prefixes of the vector still work — smaller,
# cheaper, slightly blurrier.)

# %%
# 5.1 — your code here

# %%
# 5.2 — your code here

# %%
# 5.3 — your code here

# %%
# 5.4 — your code here

# %% [markdown]
# ---
# ## ✅ Checkpoint
#
# You can now: use numpy arrays, compute cosine similarity *from scratch*, and turn
# any text into a vector where distance = meaning.
#
# After lunch we scale this up: semantic search over
# **300 player reviews** — in about 15 lines of code.
