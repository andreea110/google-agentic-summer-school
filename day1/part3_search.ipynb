# %% [markdown]
# # Part 3 · Semantic search over 300 reviews
#
# **Building Agentic AI — Day 1, 11:30–12:15**
#
# Welcome back. We previously computed cosine similarity between 8 sentences.
# Now we do it *for real*: you've just joined **Playfield**, a small indie game
# storefront, as its first data person. You have 20 games, 300 player reviews,
# and one recurring request from the studios: *"what are players actually saying?"*
#
# In this notebook you build the answer machine: **semantic search** — find reviews
# by *meaning*, not keywords. It's the "R" in RAG, and on Day 3 your agent will
# call the function you write today.

# %%
import os
import time
from pathlib import Path

import numpy as np
import pandas as pd
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv("../.env", override=True)  # .env wins over stale keys inherited from the kernel's environment
client = genai.Client()

EMBED_MODEL = "gemini-embedding-001"

pd.set_option("display.max_colwidth", 100)

# %% [markdown]
# ## 1. Meet the dataset
#
# Two CSVs — the game catalog and the player reviews. (A crash course in `pandas`
# happens naturally in the next ten cells; watch what each line does to the table.)

# %%
games = pd.read_csv("../data/games.csv")
games
# Out:
#    game_id                   title                   genre  price_eur  \
# 0      g01       Neon Drift Racers           Arcade racing      19.99
# 1      g02         Dungeon Sprouts          Cozy roguelite      14.99
# 2      g03       Star Salvage Crew         Co-op space sim      24.99
# 3      g04      Castle Contractors            Building sim      29.99
# 4      g05    Pixel Pirates Online        Free-to-play MMO       0.00
# 5      g06            Kernel Panic       Hacking roguelike      12.99
# 6      g07     Haunted Spreadsheet       Horror comedy sim       9.99
# 7      g08              Orbit Fall      Physics platformer       7.99
# 8      g09              Moth Light            Metroidvania      17.99
# 9      g10  Turbo Goat Simulator 9            Meme sandbox       6.99
# 10     g11        Chess Royale 100  Strategy battle royale       0.00
# 11     g12           Silent Depths         Survival horror      21.99
# 12     g13          Bureau of Time     Detective adventure      18.99
# 13     g14            Mecha Garden        Mech farming sim      15.99
# 14     g15           Rooftop Ramen   Restaurant management      11.99
# 15     g16            Glacier Punk     Open-world survival      34.99
# 16     g17         Wizard Landlord          Management sim      13.99
# 17     g18            Farm & Forge        Farming crafting      19.99
# 18     g19       Speedrun Sandwich          Action cooking       8.99
# 19     g20            Echo Tactics      Turn-based tactics      24.99
#
#     release_year           developer
# 0           2024      Velocity Forge
# 1           2023       Tiny Cauldron
# 2           2025        Orbital Labs
# 3           2024  Drawbridge Digital
# 4           2022  Kraken Interactive
# 5           2025  Null Pointer Games
# 6           2024  Cursed Cell Studio
# 7           2023    Weightless Whale
# 8           2025  Lantern Collective
# 9           2024       Chaos Pasture
# 10          2023     Checkmate Cloud
# 11          2025       Abyssal Point
# 12          2024    Clockwise Bureau
# 13          2025          Iron Petal
# 14          2023          Broth Bros
# 15          2026     Coldsnap Studio
# 16          2024        Arcane Lease
# 17          2022        Anvil & Acre
# 18          2025     Deli Dash Games
# 19          2024        Quiet Signal

# %%
reviews = pd.read_csv("../data/reviews.csv")
print(f"{len(reviews)} reviews")
reviews.head(3)
# Out:
# 300 reviews
#   review_id game_id             author  hours_played  recommended  \
# 0      r001     g14  irrigation_nation          36.0         True
# 1      r002     g18   prodigal_planter         344.7         True
# 2      r003     g11        pawn_fodder           6.3        False
#
#    helpful_votes        date  \
# 0              9  2025-11-22
# 1             48  2026-05-22
# 2             19  2023-08-30
#
#                                                                                            review_text
# 0  The customization depth surprised me: swapped my Trowel-9's shoulder cannon for an irrigation dr...
# 1  Came back after a year away for the 2.0 Reforged update and it is everything the old roadmap pro...
# 2                                   Rank 2 and I keep getting paired against actual grandmasters. Why.

# %% [markdown]
# `pandas` one-liners answer the easy questions instantly:

# %%
reviews["recommended"].mean()          # fraction of thumbs-up overall
# Out:
# np.float64(0.7033333333333334)

# %%
reviews["hours_played"].describe().round(1)
# Out:
# count     300.0
# mean       55.0
# std       104.8
# min         0.8
# 25%        12.0
# 50%        28.6
# 75%        58.1
# max      1150.0
# Name: hours_played, dtype: float64

# %% [markdown]
# `merge` joins the two tables on `game_id`, so every review knows its game's
# title, genre and price — we'll work with this combined table from now on:

# %%
df = reviews.merge(games, on="game_id")
df[["review_id", "title", "recommended", "hours_played", "review_text"]].head(3)
# Out:
#   review_id             title  recommended  hours_played  \
# 0      r001      Mecha Garden         True          36.0
# 1      r002      Farm & Forge         True         344.7
# 2      r003  Chess Royale 100        False           6.3
#
#                                                                                            review_text
# 0  The customization depth surprised me: swapped my Trowel-9's shoulder cannon for an irrigation dr...
# 1  Came back after a year away for the 2.0 Reforged update and it is everything the old roadmap pro...
# 2                                   Rank 2 and I keep getting paired against actual grandmasters. Why.

# %% [markdown]
# Which games do players love — and which are in trouble?

# %%
rating = df.groupby("title")["recommended"].mean().sort_values()
rating.plot(kind="barh", figsize=(7, 6), title="Share of positive reviews per game");

# %% [markdown]
# Read a few raw reviews to get a feel for the *texture* of this data — typos,
# sarcasm, ALL CAPS, the occasional Romanian:

# %%
for text in df.sample(3, random_state=7)["review_text"]:
    print("—" * 70)
    print(text)
# Out:
# ——————————————————————————————————————————————————————————————————————
# As someone who has finished basically every metroidvania worth playing: the movement kit here is top three ever. The Chandler fight forces you to use every tool you've unlocked and it's glorious. Ability gating is smart, secrets reward genuine curiosity, and yes, you can break the intended route in at least four places. The map deserved another design pass, but the world underneath it is exceptional.
# ——————————————————————————————————————————————————————————————————————
# Finished in one hour fifty-four. Even at ten euro that stings when the store page says nothing about length. Brilliant concept, criminally brief. Wait for a sale or a content update.
# ——————————————————————————————————————————————————————————————————————
# Bought it right after the big 2.0 update. Zero regrets.

# %% [markdown]
# ## 2. Keyword search — and where it breaks
#
# The obvious approach: `str.contains`.

# %%
def keyword_search(query):
    hits = df[df["review_text"].str.contains(query, case=False, regex=False)]
    return hits[["title", "review_text"]]


keyword_search("crash").head()
# Out:
#                       title  \
# 3         Neon Drift Racers
# 124  Turbo Goat Simulator 9
# 187           Silent Depths
# 219       Star Salvage Crew
# 249       Neon Drift Racers
#
#                                                                                              review_text
# 3    Came back after patch 1.4 and the crashing is completely gone. Three-hour session last night, ze...
# 124  Strapped a jetpack to my goat, crashed a wedding, got the bride's bouquet stuck to my tongue, dr...
# 187  Save file vanished after a crash on Deck C. My support ticket has been open for three weeks with...
# 219  The January netcode overhaul actually delivered. Movement is server-side now, rubber-banding is ...
# 249  Loved this game until patch 1.3. Now it crashes to desktop every second or third race, usually r...

# %% [markdown]
# Works! Until the player types something the reviewer didn't:

# %%
print(len(keyword_search("crash")), "hits for 'crash'")
print(len(keyword_search("game keeps freezing")), "hits for 'game keeps freezing'")
print(len(keyword_search("predatory monetization")), "hits for 'predatory monetization'")
# Out:
# 5 hits for 'crash'
# 0 hits for 'game keeps freezing'
# 0 hits for 'predatory monetization'

# %% [markdown]
# Zero hits — yet you *know* reviews complain about freezes and cash grabs; they just
# use different words ("CTD", "hangs", "wallet warriors", "pay-to-win"...).
# Keyword search matches **spelling**. We need to match **meaning**.

# %% [markdown]
# ## 3. Embed the whole corpus (batched, cached, retry-safe)
#
# Same as this morning, at scale: one 768-dim vector per review. Three bits of
# engineering that mark the difference between a demo and something that survives
# contact with reality:
#
# - **batching** — the API takes up to ~100 texts per call, so we send chunks,
# - **retries with backoff** — free-tier rate limits (HTTP 429) are a *when*, not an *if*,
# - **caching** — embeddings don't change; compute once, save to disk, reload forever.

# %%
CACHE = Path("cache")
CACHE.mkdir(exist_ok=True)
EMB_FILE = CACHE / "review_embeddings.npy"


def embed_texts(texts, task_type, batch_size=64):
    """Embed a list of texts → normalized (len(texts), 768) matrix."""
    vectors = []
    for start in range(0, len(texts), batch_size):
        batch = texts[start : start + batch_size]
        for attempt in range(7):
            try:
                result = client.models.embed_content(
                    model=EMBED_MODEL,
                    contents=batch,
                    config=types.EmbedContentConfig(
                        task_type=task_type,
                        output_dimensionality=768,
                    ),
                )
                vectors.extend(e.values for e in result.embeddings)
                break
            except genai.errors.APIError as err:
                wait = 2**attempt
                print(f"  API error {err.code}: {err.message}")
                print(f"  retrying in {wait}s…")
                time.sleep(wait)
        else:
            raise RuntimeError("embedding failed after 7 attempts")
        print(f"  embedded {min(start + batch_size, len(texts))}/{len(texts)}")
    E = np.array(vectors)
    return E / np.linalg.norm(E, axis=1, keepdims=True)


if EMB_FILE.exists():
    doc_vecs = np.load(EMB_FILE)
    print("loaded from cache ✅")
else:
    doc_vecs = embed_texts(df["review_text"].tolist(), task_type="RETRIEVAL_DOCUMENT")
    np.save(EMB_FILE, doc_vecs)

doc_vecs.shape
# Out:
# loaded from cache ✅
# (300, 768)

# %% [markdown]
# One subtlety: `task_type="RETRIEVAL_DOCUMENT"` for the corpus, but
# `RETRIEVAL_QUERY` for searches. Queries and documents are phrased differently
# ("crashes on startup?" vs "the game died again, third time today") — Gemini
# embeddings are trained to map the *question* and the *answer* close together
# when you label which is which.

# %% [markdown]
# ## 4. The search function — 15 lines, as promised

# %%
def search(query, top_k=5):
    result = client.models.embed_content(
        model=EMBED_MODEL,
        contents=query,
        config=types.EmbedContentConfig(
            task_type="RETRIEVAL_QUERY",
            output_dimensionality=768,
        ),
    )
    q = np.array(result.embeddings[0].values)
    q = q / np.linalg.norm(q)

    scores = doc_vecs @ q                      # cosine similarity vs every review at once
    top = np.argsort(scores)[::-1][:top_k]     # best k indices

    hits = df.iloc[top][["review_id", "title", "recommended", "review_text"]].copy()
    hits.insert(0, "score", scores[top].round(3))
    return hits

# %% [markdown]
# That's the whole engine. Let's interrogate it — starting with the query that
# keyword search fumbled:

# %%
search("game keeps freezing")
# Out:
#      score review_id               title  recommended  \
# 200  0.670      r201   Neon Drift Racers        False
# 36   0.660      r037   Neon Drift Racers         True
# 120  0.653      r121  Castle Contractors        False
# 52   0.649      r053        Glacier Punk         True
# 62   0.648      r063   Neon Drift Racers        False
#
#                                                                                              review_text
# 200  I was 40 hours in and hosting weekly time-trial nights with my club. Since the update the game f...
# 36   game dies after the update at least once a night, usualy mid drift. still cant quit it tho. the ...
# 120  my laptop sounds like a trebuchet winding up whenever i load my big castle. 12 fps in the courty...
# 52   Built my base into the side of a crevasse and rigged geothermal heating, then a patch moved the ...
# 62                         hangs on the loading screen since the update. stared at neon for ten minutes.

# %%
search("predatory monetization")
# Out:
#      score review_id                 title  recommended  \
# 42   0.682      r043          Echo Tactics        False
# 208  0.678      r209  Pixel Pirates Online        False
# 39   0.661      r040  Pixel Pirates Online        False
# 213  0.645      r214  Pixel Pirates Online        False
# 266  0.645      r267          Echo Tactics        False
#
#                                                                                              review_text
# 42   Half the units are paywalled. The Iron Choir pack alone costs 15 euro on top of a 25 euro game, ...
# 208                                          free to play, pay to win, hard to quit, uninstalled anyway.
# 39                                                           fomo pass, login queue, whale food. im out.
# 213  As a free player I grinded three weeks for the storm sails. A whale buys them in three seconds w...
# 266  Base game ships with twelve units and the balance patch notes casually discuss units I do not ev...

# %%
search("this game made me cry")
# Out:
#      score review_id            title  recommended  \
# 143  0.738      r144       Moth Light         True
# 275  0.720      r276   Bureau of Time         True
# 33   0.713      r034  Dungeon Sprouts         True
# 148  0.709      r149  Dungeon Sprouts         True
# 197  0.704      r198     Farm & Forge         True
#
#                                                                                              review_text
# 143  I don't cry at games. I cried at this one. Every frame of the hand-drawn art looks like it took ...
# 275  Solved the case at 2am and just sat there in the dark afterwards. No game has ever done that to ...
# 33   the little guys. the LITTLE GUYS. i grew a radish paladin and cired when he sacrificed himself f...
# 148  I picked this up during a rough patch of my life and it was exactly what I needed. Nothing in it...
# 197  The autumn festival made me tear up a little. Farm and Forge understands coziness on a level mos...

# %%
search("great to play with friends")
# Out:
#      score review_id              title  recommended  \
# 26   0.712      r027  Speedrun Sandwich         True
# 202  0.708      r203  Star Salvage Crew         True
# 166  0.704      r167  Speedrun Sandwich         True
# 298  0.698      r299  Speedrun Sandwich         True
# 167  0.698      r168    Wizard Landlord         True
#
#                                                                                              review_text
# 26   Every session generates a story. Last night someone launched the Tower of Bologna across the kit...
# 202                                      friend pass means my whole squad plays on one copy. based devs.
# 166  Bought four copies for game night and it paid for itself in one evening. Simple to learn, imposs...
# 298  Four players, one kitchen, ninety seconds, a bread catapult. We screamed so much the neighbors c...
# 167  Perfect evening game. Collect rent, read letters, laugh out loud, renovate a haunted attic, repe...

# %% [markdown]
# And because embeddings are multilingual — **search in Romanian, find English reviews**:

# %%
search("jocul se blochează la încărcare")
# Out:
#      score review_id              title  recommended  \
# 62   0.717      r063  Neon Drift Racers        False
# 211  0.673      r212       Echo Tactics         True
# 281  0.657      r282    Dungeon Sprouts         True
# 268  0.653      r269       Echo Tactics         True
# 153  0.651      r154   Chess Royale 100        False
#
#                                                                                              review_text
# 62                         hangs on the loading screen since the update. stared at neon for ten minutes.
# 211  Cel mai bun joc de tactica pe ture din ultimii ani, pe bune, fiecare tura e un puzzle. Singura p...
# 281  l-am luat pentru nepotu-miu si acum ne certam pe rand la PC. e genul de joc care te face sa zici...
# 268  45 second loads into every skirmish on a Samsung 980 Pro. An NVMe drive should not feel like a c...
# 153  Ideea e geniala, sah cu 100 de oameni pe aceeasi tabla uriasa, ce sa zic. Dar la fiecare doua me...

# %% [markdown]
# Side-by-side, the difference in one picture:

# %%
q = "game keeps freezing"
print(f"KEYWORD  '{q}' → {len(keyword_search(q))} hits")
print(f"SEMANTIC '{q}' → top hit: {search(q, top_k=1)['review_text'].iloc[0][:100]}…")
# Out:
# KEYWORD  'game keeps freezing' → 0 hits
# SEMANTIC 'game keeps freezing' → top hit: I was 40 hours in and hosting weekly time-trial nights with my club. Since the update the game freez…

# %% [markdown]
# ## 5. Exercises
#
# **5.1 — Scoped search (⭐)** Write `search_game(query, title, top_k=5)` that only
# searches within one game's reviews. Hint: build a boolean mask from `df["title"]`,
# apply it to *both* `df` and `doc_vecs` (numpy accepts boolean masks too).
#
# **5.2 — Most similar pair (⭐⭐)** Find the two *most similar reviews* in the whole
# corpus. Hints: `S = doc_vecs @ doc_vecs.T`, kill the diagonal with
# `np.fill_diagonal(S, -1)`, then `np.unravel_index(S.argmax(), S.shape)`.
# Are they for the same game? Same complaint in different words?
#
# **5.3 — More like this (⭐)** Write `more_like_this(review_id, top_k=5)`.
# No new embedding needed — the review's vector is already a row of `doc_vecs`.
#
# **5.4 — Honest search (⭐⭐)** Modify `search` to drop results scoring below a
# threshold (try `0.5`). Then search for `"quantum physics homework"`.
# Returning *nothing* is the correct answer — remember this on Day 3, when an
# agent must decide whether its retrieval tool actually found anything.

# %%
# 5.1 — your code here

def search_game(query, top_k=5):
    mask = (df["title"].str.lower() == query.lower())
    sub_df, sub_vecs = df[mask], doc_vecs[mask]

    scores = sub_vecs @ embeded_query(query)
    top = np.argsort(scores)[::-1][:top_k]

    hits = sub_df.iloc[top][["review_id", "recommended", "review_text"]].copy()
    hits.insert(0, "score", scores[top].round(3))
    return hits

search_game("carshes and freezes", "Neon Drift Racers")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 14
#      11     hits.insert(0, "score", scores[top].round(3))
#      12     return hits
# ---> 14 search_game("carshes and freezes", "Neon Drift Racers")
#
# Cell In[25], line 7, in search_game(query, top_k)
#       4 mask = (df["title"].str.lower() == query.lower())
#       5 sub_df, sub_vecs = df[mask], doc_vecs[mask]
# ----> 7 scores = sub_vecs @ embeded_query(query)
#       8 top = np.argsort(scores)[::-1][:top_k]
#      10 hits = sub_df.iloc[top][["review_id", "recommended", "review_text"]].copy()
#
# NameError: name 'embeded_query' is not defined

# %%
# 5.2 — your code here

# %%
# 5.3 — your code here

# %%
# 5.4 — your code here

# %% [markdown]
# ---
# ## ✅ Checkpoint
#
# You built a semantic search engine over a real(istic) corpus: batched + cached
# embeddings, cosine ranking, honest no-answer handling. **You built the "R" in RAG.**
#
# ☕ **Short break.** In Part 4 the model starts working *for* you: turning messy
# review prose into clean, analyzable rows — the last skill your Friday agent needs.
